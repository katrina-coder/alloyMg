# %% [markdown]
# <a href="https://colab.research.google.com/github/katrina-coder/MgAlloyPublic/blob/main/MgAlloyPublic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#@title GUI Startup
if 'google.colab' in str(get_ipython()):
    # !git clone https://github.com/katrina-coder/MgAlloyPublic &> /dev/null 
    # !pip install scikit-learn==0.24.1 &> /dev/null 
    from MgAlloyPublic.optimiserGUI import *
else: 
    from optimiserGUI import *
    
generateModeSelectionGUI()
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:315: UserWarning: Trying to unpickle estimator DecisionTreeRegressor from version 0.23.2 when using version 0.24.1. This might lead to breaking code or invalid results. Use at your own risk.
#   UserWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:315: UserWarning: Trying to unpickle estimator RandomForestRegressor from version 0.23.2 when using version 0.24.1. This might lead to breaking code or invalid results. Use at your own risk.
#   UserWarning)
# Dropdown(description='<b>Select Mode:</b>', options=('Mechanical',), style=DescriptionStyle(description_width=…
# HBox(children=(VBox(children=(HTML(value='<b>Range-based Inputs (wt. %)    </b>'), HBox(children=(Label(value=…
# Button(description='Run Model', style=ButtonStyle())
# start running model ....
# ==========Scan Finished==========
# Predicted 10.266964 Elongation
# Predicted 124.747605 Yield Strength
# Predicted 210.827969 Tensile Strength
# start running model ....
# ==========Scan Finished==========
# Predicted 4.328398 Elongation
# Predicted 569.705516 Yield Strength
# Predicted 690.926563 Tensile Strength
# start running model ....
# ==========Scan Finished==========
# Predicted 4.328398 Elongation
# Predicted 569.705516 Yield Strength
# Predicted 690.926563 Tensile Strength
# start running model ....
# ==========Scan Finished==========
# Predicted 4.328398 Elongation
# Predicted 569.705516 Yield Strength
# Predicted 690.926563 Tensile Strength
